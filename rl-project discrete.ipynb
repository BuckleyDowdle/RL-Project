# %%
# utility imports
import os
import numpy as np
import pandas as pd

#env imports
import gym
from pettingzoo.butterfly import cooperative_pong_v2
import supersuit as ss

#Algoritm Imports
from stable_baselines3.ppo import CnnPolicy, MlpPolicy
from stable_baselines3.a2c import CnnPolicy, MlpPolicy
from stable_baselines3 import PPO, A2C

# %%
from pettingzoo.sisl import multiwalker_v6
env = multiwalker_v6.parallel_env(n_walkers=2, position_noise=1e-3, angle_noise=1e-3, local_ratio=1.0,
forward_reward=1.0, terminate_reward=-100.0, fall_reward=-10.0, terminate_on_fall=True, remove_on_fall=True,
max_cycles=500) #create env
agents= ['walker_0', 'walker_1'] #name agents
#env = ss.color_reduction_v0(env, mode='B') #convert to grayscale for less computation
#env = ss.resize_v0(env, x_size=84, y_size=84) #resive
#env = ss.frame_stack_v1(env, 4)#stack 4 frames together to see velocity/direction
env = ss.pettingzoo_env_to_vec_env_v0(env) #convert to vec env
env = ss.concat_vec_envs_v0(env, 1, num_cpus=1, base_class='stable_baselines3') #parallelize

# %%
env = cooperative_pong_v2.parallel_env(ball_speed=9, left_paddle_speed=12, right_paddle_speed=12, cake_paddle=False, max_cycles=2000, bounce_randomness=False) #create env
agents= ['paddle_0', 'paddle_1'] #name agents
env = ss.color_reduction_v0(env, mode='B') #convert to grayscale for less computation
env = ss.resize_v0(env, x_size=84, y_size=84) #resive
env = ss.frame_stack_v1(env, 4)#stack 4 frames together to see velocity/direction
env = ss.pettingzoo_env_to_vec_env_v0(env) #convert to vec env
env = ss.concat_vec_envs_v0(env, 1, num_cpus=1, base_class='stable_baselines3') #parallelize

# %%
model = PPO(MlpPolicy, env)

# %%
model.learn(total_timesteps = 100)

# %%
model = PPO(CnnPolicy, env,  learning_rate=0.0003, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, gae_lambda=0.95, clip_range=0.2,
            clip_range_vf=1, ent_coef=0.0, vf_coef=0.5, max_grad_norm=0.5, use_sde=False, sde_sample_freq=- 1, target_kl=None, 
            tensorboard_log=None, create_eval_env=False, policy_kwargs=None, verbose=1, seed=314, device='auto', _init_setup_model=True)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
os.chdir('log')

# %%
for steps in range(2048,(20480*5),2048):
    model.learn(total_timesteps = steps)
    
    policy = str(steps)
    model.save(policy)
    print(policy + ' complete!')
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 618  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 4096 |
# -----------------------------
# 2048 complete!
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 505          |
# |    iterations           | 1            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | -0.014404828 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 1            |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -6.46e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0234      |
# |    value_loss           | 289          |
# ------------------------------------------
# 4096 complete!
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 525          |
# |    iterations           | 1            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | -0.013050668 |
# |    clip_fraction        | 0.483        |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 1            |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.00371     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 165          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0593      |
# |    value_loss           | 384          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 2            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | -0.022827666 |
# |    clip_fraction        | 0.581        |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 1            |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | -0.0404      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0464      |
# |    value_loss           | 233          |
# ------------------------------------------
# 6144 complete!
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.087873556 |
# |    clip_fraction        | 0.522       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | -0.0272     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00103     |
# |    value_loss           | 153         |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 160       |
# |    iterations           | 2         |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0727966 |
# |    clip_fraction        | 0.52      |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 1         |
# |    entropy_loss         | -0.91     |
# |    explained_variance   | -0.101    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 66.1      |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -0.0221   |
# |    value_loss           | 131       |
# ---------------------------------------
# 8192 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 520        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.14488295 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.844     |
# |    explained_variance   | 0.12       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 48.7       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.000632  |
# |    value_loss           | 83.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 2           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.104370914 |
# |    clip_fraction        | 0.503       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.0166      |
# |    value_loss           | 68.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 3          |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.10007453 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.796     |
# |    explained_variance   | 0.128      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.2       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00583   |
# |    value_loss           | 53.5       |
# ----------------------------------------
# 10240 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 521        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.09472152 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.857     |
# |    explained_variance   | 0.0895     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.2       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.00925    |
# |    value_loss           | 54.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 2           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.077042386 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00643    |
# |    value_loss           | 46.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 3           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.078422956 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0.0614      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 48.1        |
# -----------------------------------------
# 12288 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 514        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.09206557 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.847     |
# |    explained_variance   | 0.278      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.2       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.012     |
# |    value_loss           | 43.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 157        |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.05196038 |
# |    clip_fraction        | 0.45       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.852     |
# |    explained_variance   | 0.228      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.7       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00514   |
# |    value_loss           | 52.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 3           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.061996423 |
# |    clip_fraction        | 0.44        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 51.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 4          |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.07433655 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.855     |
# |    explained_variance   | 0.196      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.3       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00171   |
# |    value_loss           | 48.5       |
# ----------------------------------------
# 14336 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 520        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.07493837 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.824     |
# |    explained_variance   | 0.243      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.9       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 52.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 157        |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.08240515 |
# |    clip_fraction        | 0.436      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.838     |
# |    explained_variance   | 0.201      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.2       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00372   |
# |    value_loss           | 53.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 3           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.061253592 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00559    |
# |    value_loss           | 49.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 4          |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.08149761 |
# |    clip_fraction        | 0.392      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.753     |
# |    explained_variance   | 0.175      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.3       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0105    |
# |    value_loss           | 54.4       |
# ----------------------------------------
# 16384 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 519        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.07660715 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.778     |
# |    explained_variance   | 0.254      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15         |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.00355    |
# |    value_loss           | 45.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.08568969 |
# |    clip_fraction        | 0.438      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.784     |
# |    explained_variance   | 0.236      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.1       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0213    |
# |    value_loss           | 61.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 3          |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.14236438 |
# |    clip_fraction        | 0.449      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.768     |
# |    explained_variance   | 0.214      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.4       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00957   |
# |    value_loss           | 54.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 4          |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.11608923 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.734     |
# |    explained_variance   | 0.412      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.4       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 39.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 5          |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.16193026 |
# |    clip_fraction        | 0.359      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.725     |
# |    explained_variance   | 0.311      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21         |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00623   |
# |    value_loss           | 44.5       |
# ----------------------------------------
# 18432 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 524        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.13849303 |
# |    clip_fraction        | 0.334      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.761     |
# |    explained_variance   | 0.13       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.3       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.00133    |
# |    value_loss           | 57.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.20299083 |
# |    clip_fraction        | 0.357      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.697     |
# |    explained_variance   | 0.329      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.1       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0188     |
# |    value_loss           | 58         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 3          |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.20343065 |
# |    clip_fraction        | 0.383      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.655     |
# |    explained_variance   | 0.244      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.4       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.0202     |
# |    value_loss           | 61.7       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 120       |
# |    iterations           | 4         |
# |    time_elapsed         | 136       |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.1592459 |
# |    clip_fraction        | 0.32      |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 1         |
# |    entropy_loss         | -0.615    |
# |    explained_variance   | 0.00748   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 20.9      |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -0.00351  |
# |    value_loss           | 58.4      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 5          |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.12959613 |
# |    clip_fraction        | 0.311      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.624     |
# |    explained_variance   | 0.0485     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.4       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0435     |
# |    value_loss           | 60.6       |
# ----------------------------------------
# 20480 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 494        |
# |    iterations           | 1          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.14619778 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.666     |
# |    explained_variance   | 0.0982     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.2       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.00437    |
# |    value_loss           | 64.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 157        |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.18006489 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.628     |
# |    explained_variance   | -0.075     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.1       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0414     |
# |    value_loss           | 68.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 3          |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.13352764 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.729     |
# |    explained_variance   | 0.19       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.1       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.00604    |
# |    value_loss           | 46.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 4          |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.14917362 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.765     |
# |    explained_variance   | 0.332      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.5       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00358    |
# |    value_loss           | 53.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 5          |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.13717166 |
# |    clip_fraction        | 0.381      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.74      |
# |    explained_variance   | 0.287      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.6       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0107     |
# |    value_loss           | 50.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 6          |
# |    time_elapsed         | 220        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.18668541 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.712     |
# |    explained_variance   | 0.324      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.6       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.00399    |
# |    value_loss           | 63.6       |
# ----------------------------------------
# 22528 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 513        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.10325875 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.753     |
# |    explained_variance   | 0.485      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.6       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00602   |
# |    value_loss           | 44.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 160        |
# |    iterations           | 2          |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.12769657 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.783     |
# |    explained_variance   | 0.376      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.3       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.000539  |
# |    value_loss           | 54.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 3          |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.12845774 |
# |    clip_fraction        | 0.461      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.817     |
# |    explained_variance   | 0.198      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.1       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00952   |
# |    value_loss           | 50.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 4          |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.12638998 |
# |    clip_fraction        | 0.434      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.74      |
# |    explained_variance   | 0.2        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.3       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0024     |
# |    value_loss           | 59.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 5           |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.093417354 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 57.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 6          |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.10643348 |
# |    clip_fraction        | 0.422      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.739     |
# |    explained_variance   | 0.31       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28.7       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 50.5       |
# ----------------------------------------
# 24576 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 513        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.11815271 |
# |    clip_fraction        | 0.416      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.769     |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.7       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00666   |
# |    value_loss           | 53.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 160        |
# |    iterations           | 2          |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.11255947 |
# |    clip_fraction        | 0.473      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.758     |
# |    explained_variance   | 0.284      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.5       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.000162   |
# |    value_loss           | 53.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 3          |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.11862831 |
# |    clip_fraction        | 0.449      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.782     |
# |    explained_variance   | 0.15       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.4       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00866   |
# |    value_loss           | 60.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 4          |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.09354642 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.759     |
# |    explained_variance   | 0.313      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.8       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00589   |
# |    value_loss           | 54.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 5          |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.12393643 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.704     |
# |    explained_variance   | 0.276      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.4       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 53         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 6          |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.12479618 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.759     |
# |    explained_variance   | 0.266      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.5       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00169   |
# |    value_loss           | 70         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 7          |
# |    time_elapsed         | 260        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.12742697 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.73      |
# |    explained_variance   | 0.23       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28.1       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00697   |
# |    value_loss           | 61.5       |
# ----------------------------------------
# 26624 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 515        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.08385742 |
# |    clip_fraction        | 0.384      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.713     |
# |    explained_variance   | 0.305      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.2       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.000621   |
# |    value_loss           | 66         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 160        |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.14313954 |
# |    clip_fraction        | 0.458      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.742     |
# |    explained_variance   | 0.207      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.1       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 69.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 3          |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.19615766 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.741     |
# |    explained_variance   | 0.245      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.9       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00955   |
# |    value_loss           | 59.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 4          |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.11144862 |
# |    clip_fraction        | 0.421      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.719     |
# |    explained_variance   | 0.326      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 42.6       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00803   |
# |    value_loss           | 51.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 5          |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.13113537 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.707     |
# |    explained_variance   | 0.362      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.7       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.00651   |
# |    value_loss           | 51.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 6          |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.18077888 |
# |    clip_fraction        | 0.472      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.72      |
# |    explained_variance   | 0.229      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 52         |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0178    |
# |    value_loss           | 66.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 7           |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.120343216 |
# |    clip_fraction        | 0.461       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.2        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.00114     |
# |    value_loss           | 73.6        |
# -----------------------------------------
# 28672 complete!
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 515        |
# |    iterations           | 1          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.12131307 |
# |    clip_fraction        | 0.46       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.719     |
# |    explained_variance   | 0.228      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32         |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.00188   |
# |    value_loss           | 60.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 2           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.111699894 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 68.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 3           |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.111723155 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.2        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 54          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 4          |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.12229974 |
# |    clip_fraction        | 0.433      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.672     |
# |    explained_variance   | 0.253      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.7       |
# |    n_updates            | 590        |
# |    policy_gradient_loss | 0.00298    |
# |    value_loss           | 65.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 5          |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.17310967 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.757     |
# |    explained_variance   | 0.191      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.5       |
# |    n_updates            | 600        |
# |    policy_gradient_loss | 0.00203    |
# |    value_loss           | 56.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 6          |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.14499336 |
# |    clip_fraction        | 0.483      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.726     |
# |    explained_variance   | 0.173      |
# ...
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.195      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.2       |
# |    n_updates            | 6040       |
# |    policy_gradient_loss | 0.00132    |
# |    value_loss           | 68.1       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 100       |
# |    iterations           | 6         |
# |    time_elapsed         | 243       |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.1547586 |
# |    clip_fraction        | 0.389     |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 1         |
# |    entropy_loss         | -0.578    |
# |    explained_variance   | 0.252     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 26.1      |
# |    n_updates            | 6050      |
# |    policy_gradient_loss | -0.00584  |
# |    value_loss           | 77.8      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 7          |
# |    time_elapsed         | 291        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.12343196 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.58      |
# |    explained_variance   | 0.358      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57         |
# |    n_updates            | 6060       |
# |    policy_gradient_loss | 0.0027     |
# |    value_loss           | 52.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 8          |
# |    time_elapsed         | 338        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.17961177 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.529     |
# |    explained_variance   | 0.332      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 50.8       |
# |    n_updates            | 6070       |
# |    policy_gradient_loss | -0.0115    |
# |    value_loss           | 72.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 9          |
# |    time_elapsed         | 385        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.17155382 |
# |    clip_fraction        | 0.339      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.527     |
# |    explained_variance   | 0.369      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 62.6       |
# |    n_updates            | 6080       |
# |    policy_gradient_loss | 0.00153    |
# |    value_loss           | 70.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 10         |
# |    time_elapsed         | 432        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.15690312 |
# |    clip_fraction        | 0.348      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.553     |
# |    explained_variance   | 0.321      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 51.2       |
# |    n_updates            | 6090       |
# |    policy_gradient_loss | 0.0145     |
# |    value_loss           | 60.5       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 93        |
# |    iterations           | 11        |
# |    time_elapsed         | 479       |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.1387041 |
# |    clip_fraction        | 0.298     |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 1         |
# |    entropy_loss         | -0.449    |
# |    explained_variance   | 0.448     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 52.2      |
# |    n_updates            | 6100      |
# |    policy_gradient_loss | 0.0181    |
# |    value_loss           | 66        |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 12         |
# |    time_elapsed         | 526        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.18118143 |
# |    clip_fraction        | 0.304      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.49      |
# |    explained_variance   | 0.425      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.5       |
# |    n_updates            | 6110       |
# |    policy_gradient_loss | -0.00158   |
# |    value_loss           | 50.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 13         |
# |    time_elapsed         | 573        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.19118224 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.506     |
# |    explained_variance   | 0.202      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.4       |
# |    n_updates            | 6120       |
# |    policy_gradient_loss | 0.0106     |
# |    value_loss           | 76.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 14         |
# |    time_elapsed         | 620        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.16017431 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.442     |
# |    explained_variance   | 0.411      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.5       |
# |    n_updates            | 6130       |
# |    policy_gradient_loss | 0.0017     |
# |    value_loss           | 51.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 15         |
# |    time_elapsed         | 667        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.20246385 |
# |    clip_fraction        | 0.335      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.383     |
# |    explained_variance   | 0.264      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.1       |
# |    n_updates            | 6140       |
# |    policy_gradient_loss | -0.00679   |
# |    value_loss           | 58.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 16         |
# |    time_elapsed         | 714        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.22276701 |
# |    clip_fraction        | 0.32       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.379     |
# |    explained_variance   | 0.352      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.6       |
# |    n_updates            | 6150       |
# |    policy_gradient_loss | -0.00262   |
# |    value_loss           | 66.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 17         |
# |    time_elapsed         | 762        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.18024752 |
# |    clip_fraction        | 0.33       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.432     |
# |    explained_variance   | 0.295      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29         |
# |    n_updates            | 6160       |
# |    policy_gradient_loss | -0.0126    |
# |    value_loss           | 50.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 18         |
# |    time_elapsed         | 809        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.11970838 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.347     |
# |    explained_variance   | 0.256      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.9       |
# |    n_updates            | 6170       |
# |    policy_gradient_loss | -0.00711   |
# |    value_loss           | 51.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 19         |
# |    time_elapsed         | 857        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.10169432 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.482     |
# |    explained_variance   | 0.189      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 51.6       |
# |    n_updates            | 6180       |
# |    policy_gradient_loss | -0.00701   |
# |    value_loss           | 84         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 20         |
# |    time_elapsed         | 904        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.14317986 |
# |    clip_fraction        | 0.33       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.45      |
# |    explained_variance   | 0.38       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 43.7       |
# |    n_updates            | 6190       |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 76.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 21         |
# |    time_elapsed         | 951        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.17243706 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.453     |
# |    explained_variance   | 0.36       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38         |
# |    n_updates            | 6200       |
# |    policy_gradient_loss | -0.0211    |
# |    value_loss           | 59.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 22         |
# |    time_elapsed         | 998        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.19295369 |
# |    clip_fraction        | 0.339      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.416     |
# |    explained_variance   | 0.362      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46.3       |
# |    n_updates            | 6210       |
# |    policy_gradient_loss | -0.0137    |
# |    value_loss           | 82.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 23         |
# |    time_elapsed         | 1045       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.16887912 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.416     |
# |    explained_variance   | 0.406      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.4       |
# |    n_updates            | 6220       |
# |    policy_gradient_loss | -0.0108    |
# |    value_loss           | 76.9       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 89        |
# |    iterations           | 24        |
# |    time_elapsed         | 1092      |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.1678454 |
# |    clip_fraction        | 0.314     |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 1         |
# |    entropy_loss         | -0.456    |
# |    explained_variance   | 0.317     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 35.3      |
# |    n_updates            | 6230      |
# |    policy_gradient_loss | -0.0104   |
# |    value_loss           | 68.5      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 25         |
# |    time_elapsed         | 1139       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.13762832 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -0.415     |
# |    explained_variance   | 0.339      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.1       |
# |    n_updates            | 6240       |
# |    policy_gradient_loss | -0.00501   |
# |    value_loss           | 78.3       |
# ----------------------------------------
# 100352 complete!

# %%
#set up test env
env1 = cooperative_pong_v2.parallel_env(ball_speed=9, left_paddle_speed=12, right_paddle_speed=12, cake_paddle=False, max_cycles=2000, bounce_randomness=False) #create env
agents= ['paddle_0', 'paddle_1'] #name agents
env1 = ss.color_reduction_v0(env1, mode='B') #convert to grayscale for less computation
env1 = ss.resize_v0(env1, x_size=84, y_size=84) #resive
env1 = ss.frame_stack_v1(env1, 4)#stack 4 frames together to see velocity/direction
env1 = ss.pettingzoo_env_to_vec_env_v0(env1) #convert to vec env
env1 = ss.concat_vec_envs_v0(env1, 1, num_cpus=0, base_class='stable_baselines3') #parallelize, only 1 env

# %%
results = pd.DataFrame(columns = ['num_training_steps', 'avg_reward'])

# %%
num_episodes = range(100)

for count, filename in enumerate(os.listdir()):
    if filename.endswith(".zip"):
        model = PPO.load(filename.split('.')[0], env=env1)
        reward_per_ep = []

        for ep in num_episodes:

            rewards = []
            steps = 0


            obs = env1.reset()
            done = np.array([0,0])

            while all(done) != 1:
                action, _states = model.predict(obs)
                obs, reward, done, info = env1.step(action)
                steps+=1
                rewards.append(reward[0])

            reward_per_ep.append(sum(rewards)/len(rewards))


        results = results.append({'num_training_steps' : int(filename.split('.')[0]), 'avg_reward' : sum(reward_per_ep)/len(reward_per_ep)}, ignore_index = True)
# Out:
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env in a VecTransposeImage.

# %%
os.chdir('..')

# %%
results.sort_values(by=['num_training_steps'])
results.to_csv('results.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e4beffb01c10> in <module>
# ----> 1 results.sort_values(by=['num_training_steps'])
#       2 results.to_csv('results.csv')
#
# NameError: name 'results' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
results_PPO_disc = pd.read_csv('results_ppo_disc.csv')
results_PPO_disc['algorithm'] = 'PPO'

results_A2C_disc = pd.read_csv('results_a2c_disc.csv')
results_A2C_disc['algorithm'] = 'A2C'

results_disc = pd.concat([results_PPO_disc, results_A2C_disc])

# %%
plt.figure(figsize=(7,7))
sns.lineplot(x=results_disc.num_training_steps, y=results_disc.avg_reward, hue=results_disc.algorithm, ci=0);
plt.title('Average Award Per Training Steps \n Discrete Action Space');
plt.xlabel('Number of Training Steps');
plt.ylabel('Average Reward Over 100 Episodes');

# %%
results_disc
# Out:
#     num_training_steps  avg_reward algorithm
# 0               100352   -0.584735       PPO
# 1                10240   -1.086567       PPO
# 2                12288   -1.103114       PPO
# 3                14336   -0.968771       PPO
# 4                16384   -1.136953       PPO
# ..                 ...         ...       ...
# 44               20480   -1.084246       A2C
# 45               18432   -1.190466       A2C
# 46               79872   -1.080756       A2C
# 47              100352   -1.046704       A2C
# 48               96256   -1.227725       A2C
#
# [98 rows x 3 columns]
