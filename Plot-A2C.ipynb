# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
results = pd.read_csv('results3.csv')
results['algorithm'] = 'A2C'

# %%
results.sort_values(by=['num_training_steps'])
#results
# Out:
#     Unnamed: 0  num_training_steps  avg_reward algorithm
# 40          40              2048.0   -1.206409       A2C
# 37          37              4096.0   -1.153920       A2C
# 17          17              6144.0   -1.163939       A2C
# 33          33              8192.0   -1.180087       A2C
# 28          28             10240.0   -1.137967       A2C
# 39          39             12288.0   -1.056226       A2C
# 10          10             14336.0   -1.130337       A2C
# 16          16             16384.0   -1.071470       A2C
# 45          45             18432.0   -1.190466       A2C
# 44          44             20480.0   -1.084246       A2C
# 19          19             22528.0   -1.079275       A2C
# 20          20             24576.0   -1.057285       A2C
# 35          35             26624.0   -1.144164       A2C
# 2            2             28672.0   -1.097623       A2C
# 5            5             30720.0   -1.103495       A2C
# 23          23             32768.0   -1.151142       A2C
# 30          30             34816.0   -1.168545       A2C
# 41          41             36864.0   -1.072852       A2C
# 34          34             38912.0   -1.088872       A2C
# 43          43             40960.0   -1.103514       A2C
# 13          13             43008.0   -1.084860       A2C
# 8            8             45056.0   -1.073512       A2C
# 42          42             47104.0   -1.088636       A2C
# 14          14             49152.0   -1.061082       A2C
# 22          22             51200.0   -1.101409       A2C
# 0            0             53248.0   -1.002579       A2C
# 15          15             55296.0   -1.126366       A2C
# 36          36             57344.0   -1.136256       A2C
# 9            9             59392.0   -1.091780       A2C
# 4            4             61440.0   -1.099606       A2C
# 21          21             63488.0   -1.059627       A2C
# 25          25             65536.0   -1.126765       A2C
# 24          24             67584.0   -1.123250       A2C
# 31          31             69632.0   -1.103646       A2C
# 3            3             71680.0   -1.158277       A2C
# 29          29             73728.0   -1.150594       A2C
# 27          27             75776.0   -1.117386       A2C
# 7            7             77824.0   -1.043294       A2C
# 46          46             79872.0   -1.080756       A2C
# 6            6             81920.0   -1.027105       A2C
# 18          18             83968.0   -1.059133       A2C
# 32          32             86016.0   -1.102908       A2C
# 12          12             88064.0   -1.153284       A2C
# 1            1             90112.0   -1.045763       A2C
# 11          11             92160.0   -1.077003       A2C
# 26          26             94208.0   -1.164379       A2C
# 48          48             96256.0   -1.227725       A2C
# 38          38             98304.0   -1.172620       A2C
# 47          47            100352.0   -1.046704       A2C

# %%
sns.lineplot(x=results.num_training_steps, y=results.avg_reward, hue=results.algorithm );
plt.title('Average Award Per Training Steps');
plt.xlabel('Number of Training Steps');
plt.ylabel('Average Reward Over 100 Episodes');
